# %%
import requests
from bs4 import BeautifulSoup as BS
import json
import mysql.connector
import re
from art import *


try:
    page = requests.get("https://www.eventshigh.com/city/kolkata")
#     print("URL is ok!")

except:
    print("Somting wrong in url")
    


soup = BS(page.text, 'html.parser')
scraped_cards = soup.find_all(class_='ga-card-track')
# print(res[1])
all_events = []
i = 0
for i in range(len(scraped_cards)):
    all_events.append('https://www.eventshigh.com'+scraped_cards[i].find('a').get('href'))

    


if(len(all_events)<10):
    event_range = len(all_events)
else:
    event_range =10

    
    
    
    
    
all_data = []

for i in range(event_range):
    details = requests.get(all_events[i])
    details_soup = BS(details.text, 'html.parser')
    data = details_soup.find_all("script", {'type': 'application/ld+json'})
    data = '{ "ALLDATA": '+ data[2].text+ '}'
    data = json.loads(data)
    data = data["ALLDATA"][0]
#     print(data)
    organizer = data["performer"][0]['name']
    title = data['name']
    url = data['url']
    address = data['location']['name']
    price = data["offers"][0]["price"]
    image = data["image"]
    starting_date_time = data["startDate"]
    ending_date_time = data["endDate"]
    
    all_data.append({'organizer': organizer, 'title': title, 'url': url, 'address': address, 'price': price, 'image': image, 'starting_date_time': starting_date_time, 'ending_date_time': ending_date_time })
    
    print("Success!")
    
for i in range(len(all_data)):
    print(all_data[i])
    print("\n\n")
    
    
    
def mysqlConnectionInit():
    try:
        db_connection = mysql.connector.connect(
            host="localhost",
            user="root",
            passwd="1919",
            database="python"
        )
        print("Database connection is OK!")
        return db_connection
    except:
        print("Somting wrong in database connection")
        
mydb = mysqlConnectionInit()
myquery = mydb.cursor()

def insertDetailToDatabase():
    for i in range(len(all_data)):
        sql = "INSERT INTO eventshigh_com (title, organizer, url, address, price, starting_date_time, ending_date_time) VALUES (%s, %s, %s, %s, %s, %s, %s)"
        val = (all_data[i]['title'], all_data[i]['organizer'], all_data[i]['url'], all_data[i]['address'], all_data[i]['price'], all_data[i]['starting_date_time'], all_data[i]['ending_date_time'])
        try:
            myquery.execute(sql, val)
            mydb.commit()
            print("Scraping and Storing Everything Is Done. Congaratulations!")
        except:
            print("Unable to insert data")

insertDetailToDatabase()

def Interesting_url():
    for i in range(len(all_data)):
        sql = "INSERT INTO interesting_url (url, website) VALUES (%s, %s)"
        val = (all_data[i]['url'], 'eventshigh.com')
        try:
            myquery.execute(sql, val)
            mydb.commit()
            print("Interesting urls inserted")
        except:
            print("Unable to insert Interesting urls")

Interesting_url()
# Out:
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# {'organizer': 'Defined Values Consultants', 'title': 'Self-Actualized Leadership Development Workshop', 'url': 'https://www.eventshigh.com/detail/Kolkata/db0e3551f9b5ba73a7a27f75e89ce145-self-actualized-leadership-development-workshop', 'address': 'Hotel Hindusthan International', 'price': ' 3500.0 ', 'image': 'https://lh3.googleusercontent.com/15Aiu127muysXGIiYdz9z1Xa8Cu9F01pAoH7Zp1csPNsWkjkFciShzml-YC49QBGN01_jXtfEMYLYHB68d4Th_1S', 'starting_date_time': '2019-11-10T09:00:00+05:30', 'ending_date_time': '2019-11-10T18:00:00+05:30'}
#
#
#
# {'organizer': 'The Inspire India', 'title': 'How to Start your Startups-A Complete Guidance &amp; Mentoring Program', 'url': 'https://www.eventshigh.com/detail/Kolkata/f897bc3b3ed93cedf79582fbb86027b8-how-to-start-your-startups', 'address': 'OYO Townhouse 011 Esplanade', 'price': ' 3000.0 ', 'image': 'https://lh3.googleusercontent.com/I1cHQcNOhfHEgL7nWI2L1igVcV36bBKb0hAXmvQdPEoVmo1gmzUpEmoHG4Sd8n1PFJpcVhzYFVfqB6SSUhn7NQmZYw', 'starting_date_time': '2019-10-19T10:00:00+05:30', 'ending_date_time': '2019-10-19T17:00:00+05:30'}
#
#
#
# {'organizer': 'Infidea Trainings', 'title': 'One day Workshop on Advanced Excel', 'url': 'https://www.eventshigh.com/detail/Kolkata/a5421c0a90650ed9c3ea5ec1465e0481-one-day-workshop-on-advanced', 'address': 'The Senator Hotel', 'price': ' 1950.0 ', 'image': 'https://lh3.googleusercontent.com/EkrOXVqWrRcuCAdK_bfExM_Ua2y4cr4poAXmG64VC7jkok2UeOhmxuLDZn_s0EYhrvoplN6sZWz5gabHpjLOjSt5', 'starting_date_time': '2019-11-16T10:00:00+05:30', 'ending_date_time': '2019-11-16T17:30:00+05:30'}
#
#
#
# {'organizer': 'colorbarn crafts', 'title': 'Tanjore workshop', 'url': 'https://www.eventshigh.com/detail/Kolkata/45179547a0f678f8c171150b7fa1d337-tanjore-workshop', 'address': 'ColorBarn', 'price': ' 6000.0 ', 'image': 'https://storage.googleapis.com/ehimages/2019/9/1/ehsuperimposed_img_8bf6a0fb46241640468465736bf4d5f0_1567324882243_resized_1000.jpg', 'starting_date_time': '2019-10-11T11:00:00+05:30', 'ending_date_time': '2019-10-14T14:00:00+05:30'}
#
#
#
# {'organizer': 'Lean Six Sigma', 'title': 'KPMG Lean Six Sigma Green Belt Training in Kolkata', 'url': 'https://www.eventshigh.com/detail/Kolkata/ec39ee8ddb515eea1903451835b570f3-kpmg-lean-six-sigma-green', 'address': 'KPMG', 'price': ' 23600.0 ', 'image': 'https://lh3.googleusercontent.com/zUpYife6RhgzBECULw0mLJORRSOG95S8IXCFbSHKOlSs-VIUBFm4aZ3paSUeyxHs8FazNW2ybwgogADvLJ2wUB9a', 'starting_date_time': '2019-11-18T09:00:00+05:30', 'ending_date_time': '2019-11-21T17:00:00+05:30'}
#
#
#
# {'organizer': 'The Digital Web', 'title': 'Beginner&#x27;s Easy Website Design Make your own Business,eCommerce &amp; Personal sites', 'url': 'https://www.eventshigh.com/detail/Kolkata/cf5211b5d169079ba4383526a50bfbb1-beginner-s-easy-website-design', 'address': 'Hotel Hindusthan International', 'price': ' 3500.0 ', 'image': 'https://lh3.googleusercontent.com/9q7rqEAEPVnr0bCOH45czIQMD4lR7pFr1RN5hzzHXnRtz81cUtLgDRB1DuhZptQ8DoC1miBxUI2_3DNLMR72MvZY', 'starting_date_time': '2019-10-20T09:30:00+05:30', 'ending_date_time': '2019-10-20T17:30:00+05:30'}
#
#
#
# {'organizer': 'Foito', 'title': 'Big Data- Machine Learning and it&#x27;s Applications Workshop', 'url': 'https://www.eventshigh.com/detail/Kolkata/42c170f38c2fb885b545bd34dab6f0d7-big-data-machine-learning-and', 'address': 'Online On Demand', 'price': ' 5000.0 ', 'image': 'https://lh3.googleusercontent.com/l-Wd9zANI09BIyZFsR7V6XFhDYlKlu2OybycGgnscMycr9ti34IjD-FAF5oV0aEOb219I3fBa8sd6lWuHoW53VpM', 'starting_date_time': '2019-10-12T10:00:00+05:30', 'ending_date_time': '2019-10-12T15:00:00+05:30'}
#
#
#
# {'organizer': 'Foito', 'title': 'Business Launch and Audit Workshop', 'url': 'https://www.eventshigh.com/detail/Kolkata/7d885d34e3ca8f367475d12696116d0d-business-launch-and-audit-workshop', 'address': 'Online On Demand', 'price': ' 5000.0 ', 'image': 'https://lh3.googleusercontent.com/WVVBXXjCtUAC3hPI355Y4fqqBIoJafWoIH5L3jyFqc_YEKPDDQuw-sEUF628PFsDC-Ul0GjyihJmUmaLeGkZPGQw', 'starting_date_time': '2019-10-12T10:00:00+05:30', 'ending_date_time': '2019-10-12T15:00:00+05:30'}
#
#
#
# {'organizer': 'Digitalshala', 'title': 'Photography and Earning: 3 Hours Crash Workshop', 'url': 'https://www.eventshigh.com/detail/Bangalore/ecc70599f0ca771a8154c5772cd3e431-photography-and-earning-3-hours', 'address': 'Digitalshala', 'price': ' 1699.0 ', 'image': 'https://lh3.googleusercontent.com/0J9ZIz-tZJ6F9JlJyaMJmOgFVvZotj2PmkYxH6rRZVi23M_MTahJDNqJLiTLY02F6OL0pW3GeS4Y-MjCEjK-tdNU', 'starting_date_time': '2019-10-20T16:30:00+05:30', 'ending_date_time': '2019-10-20T19:30:00+05:30'}
#
#
#
# {'organizer': 'Sangini Exhibition', 'title': 'Dwali Mela', 'url': 'https://www.eventshigh.com/detail/Kolkata/3fc226345a0cc6ec14360382ad039ca5-dwali-mela', 'address': 'Siddha Pines', 'price': ' 4000.0 ', 'image': 'https://lh3.googleusercontent.com/5inzvdJBAWAOEE4SNHqdR2TPoRGUzPWaGOXoSLQgcBLPItDBTjSOfJGn8ERphD3ewLCZpDKs9DwJvMclGNMOQ-Q', 'starting_date_time': '2019-10-12T12:00:00+05:30', 'ending_date_time': '2019-10-13T21:00:00+05:30'}
#
#
#
# Database connection is OK!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Scraping and Storing Everything Is Done. Congaratulations!
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted

# %%
############################ Non-Interesting URLS ###################


urls = soup.find_all("a")
all_non_intersted_urls = []

for i in range(len(urls)):
    url = urls[i].get('href')
    url = str(url)
    x = re.search("^http", url)
    y = re.search("^//", url)
    if(x):
        url = url
    elif(y):
        url = "https:"+url
    else:
        url = "https://www.eventshigh.com"+url
    if(url != "https://www.eventshigh.comNone"):
        all_non_intersted_urls.append(url)
#     print(url)
#     print("\n")
    


def Non_interesting_url():
    for i in range(10, len(all_non_intersted_urls)):
        sql = "INSERT INTO non_interesting_url (url, website) VALUES (%s, %s)"
        val = (all_non_intersted_urls[i], 'eventshigh.com')
        try:
            myquery.execute(sql, val)
            mydb.commit()
            print("Non_interesting_urls inserted")
        except:
            print("Unable to insert Non_interesting_urls")
        


Non_interesting_url()

########################### Non-Interesting URLS ###################

tprint("Successful!")
# Out:
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
# Non_interesting_urls inserted
#  ____                                       __         _  _
# / ___|  _   _   ___   ___   ___  ___  ___  / _| _   _ | || |
# \___ \ | | | | / __| / __| / _ \/ __|/ __|| |_ | | | || || |
#  ___) || |_| || (__ | (__ |  __/\__ \\__ \|  _|| |_| || ||_|
# |____/  \__,_| \___| \___| \___||___/|___/|_|   \__,_||_|(_)
