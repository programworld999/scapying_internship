# %%
import requests
from bs4 import BeautifulSoup as BS
import json
import mysql.connector
from art import *
import re
from tqdm import tqdm
import time

# %%
try:
    page = requests.get("https://www.eventshigh.com/city/mumbai")
    print("URL is ok!")
except:
    print("Somting wrong in url")
# Out:
# URL is ok!

# %%
soup = BS(page.text, 'html.parser')
scraped_cards = soup.find_all(class_='ga-card-track')

interesting_urls = []
non_interesting_urls = []

for i in range(len(scraped_cards)):
    href = 'https://www.eventshigh.com'+scraped_cards[i].find('a').get('href')
    interesting_urls.append(href)

print(len(interesting_urls), interesting_urls)
# Out:
# 71 ['https://www.eventshigh.com/detail/mumbai/00c231ada45a7582cb88635ded585d18-scuba-diving-para-sailing-tour?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/4311dbaa31675a1e96419f77d21a2915-mumbai-dandeli-adventures-water-sports?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/fe0cd3bcb128e901438762c8bdc4e454-mumbai-the-swag-of-goa?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/d672ce19b650fd3f1b0df36ae84113db-valley-of-flowers-kaas-plateau?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/032467429ce0684d642e211f924131c1-night-trek-to-kalsubai-with?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/41b2995b42fc02880e155756721d2ba9-kalavantin-fort-one-day-trek?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/c19652633c602562f2997b1edc09ee41-night-trek-to-mt-kalsubai?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/c4db5b2206dfe5cd6899fd0d6fe30990-devkund-waterfall-trek?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/9e84d1acaa0edfee9562fbcceea8f3d5-devkund-waterfall-trek?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/c19652633c602562f2997b1edc09ee41-night-trek-to-mt-kalsubai?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/ab5532d6080016aacde8c97e38304bcb-bhandardara-lakeside-camping-on-magic?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/68d12b8a06eac6463f4a580c6093d3b2-kasol-trip-kheerganga-malana?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/f142379de8cc781930c45371df6f31d4-basic-photography-workshop-20?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/4a378f0b0b006048835f30264a323493-mesmerizing-beach-trail-kumta-to?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/f676a0fd4e14037a7ec88a8a32b9367a-the-terror-trail-colaba-by?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/b6da82713b4887286f3b7f2e8a038c43-open-mic-poetry-storytelling-standup?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/794051554eac949f6a721f0a0da4b73d-everything-about-entrepreneurship-live-seminar?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/6d7d4449ab97e77ae3acd11255ec4085-importance-of-equities-and-global?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/aa51f89037bf54a11c5a7fefc5c9cdb0-learn-to-pick-your-investments?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/512b7366040c57d48c227768840468a5-self-actualized-leadership-development-workshop?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/13c3bc7f00721f33e5a7dd5a25d3f952-finger-painting?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/8d03192fd39c8e758114b0b6769012a9-one-on-one-life-coaching?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/62ac55adc12b6d020093781b64e9d415-fluid-art-workshop?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/b86978a369adc3953a724a57e40b4250-decoupage-workshop?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/ac4f73d8301bc9e74a33fb43b4c21b11-cycling-under-the-moon-light?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/80f34c7d286abfe4021bec5565b79f85-feel-the-sound-beach-camping?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/fe950a970b10b39339c1b306f878c3ba-bombay-midnight-cycling-with-bhatakna?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/7d07646eaa89fe0c775b9de2fbcb8df7-devkund-waterfall-trek?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/270b81f1675100f5a999662cec9a0552-cycling-under-the-moonlight?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/4ed69814622d9df732d1ab2500ef5421-gond-painting-workshop?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/e5017b7242aadff3c32254bf91b3a070-midnight-cycling-under-moonlight-costal?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/ecc70599f0ca771a8154c5772cd3e431-photography-and-earning-3-hours?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/d3602d4c877caa14c5d8506302baaeeb-lakeside-camping-at-pawna?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/31d26b82391e4a080c159e23fbf7643b-kolad-river-rafting-lunch-weekend?src=ecbox', 'https://www.eventshigh. ...

# %%
data = soup.find_all('a')

for i in data:
    url = i.get('href')
#     print(url)
    x = re.search("^http", str(url))
    if(x):
        url = url
    else:
        url = "https://www.eventshigh.com"+str(url)
    if(url != "https://www.eventshigh.comNone"):
        non_interesting_urls.append(url)
    
print(len(non_interesting_urls), non_interesting_urls)
# Out:
# 337 ['https://www.eventshigh.com/mumbai/adventure+and+sports?src=searchModal', 'https://www.eventshigh.com/mumbai/attractions?src=searchModal', 'https://www.eventshigh.com/mumbai/classes+and+workshops?src=searchModal', 'https://www.eventshigh.com/mumbai/concerts+and+shows?src=searchModal', 'https://www.eventshigh.com/mumbai/food?src=searchModal', 'https://www.eventshigh.com/mumbai/fun+and+games?src=searchModal', 'https://www.eventshigh.com/mumbai/health+and+wellness?src=searchModal', 'https://www.eventshigh.com/mumbai/nature+and+parks?src=searchModal', 'https://www.eventshigh.com/mumbai/parties+and+nightlife?src=searchModal', 'https://www.eventshigh.com/mumbai/sightseeing+tours?src=searchModal', 'https://www.eventshigh.com/authenticate/facebook', 'https://www.eventshigh.com/authenticate/google', 'https://www.eventshigh.com/', 'https://www.eventshigh.com/city/mumbai', 'https://www.eventshigh.com/mumbai/today', 'https://www.eventshigh.com/mumbai/tomorrow', 'https://www.eventshigh.com/mumbai/this+weekend', 'https://www.eventshigh.com/mumbai/next+weekend', 'https://www.treebo.com/hotels-in-mumbai/?utm_source=eventshigh&utm_medium=referral&utm_campaign=mumbai_city_topbar_bookahotel', 'https://www.eventshigh.com/myevents?src=usermenu', 'https://www.eventshigh.com/myevents?src=usermenu', 'https://www.eventshigh.com/myevents?src=usermenu', 'https://www.eventshigh.com/detail/Mumbai/794051554eac949f6a721f0a0da4b73d-everything-about-entrepreneurship-live-seminar?src=stream-home', 'https://www.eventshigh.com/detail/Delhi/41d8ae86df50dd84f310241086f025b0-chadar-trek-the-frozen-zanskar?src=stream-home', 'https://www.eventshigh.com/detail/Mumbai/6d7d4449ab97e77ae3acd11255ec4085-importance-of-equities-and-global?src=stream-home', 'https://www.eventshigh.com/detail/Mumbai/aa51f89037bf54a11c5a7fefc5c9cdb0-learn-to-pick-your-investments?src=stream-home', 'https://www.eventshigh.com/detail/Mumbai/c4db5b2206dfe5cd6899fd0d6fe30990-devkund-waterfall-trek?src=stream-home', 'https://www.eventshigh.com/detail/Mumbai/20ec193e40693ec43389a4b40b881682-fort-precinct-gamifyi-d?src=stream-home', 'https://www.eventshigh.com/detail/Mumbai/3f3e0f936793810a5c33b21d2cce3df2-tc-ratangad-fort?src=stream-home', 'https://www.eventshigh.com/detail/Mumbai/13c3bc7f00721f33e5a7dd5a25d3f952-finger-painting?src=stream-home', 'https://www.eventshigh.com#', 'https://www.eventshigh.com/mumbai/dandiya?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/adventure+and+sports?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/attractions?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/classes+and+workshops?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/concerts+and+shows?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/food?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/fun+and+games?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/nature+and+parks?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/parties+and+nightlife?src=cityPage&filterDate=', 'https://www.eventshigh.com/mumbai/sightseeing+tours?src=cityPage&filterDate=', 'https://www.treebo.com/hotels-in-mumbai?utm_source=eventshigh&utm_medium=referral&utm_campaign=mumbai_category_icon', 'https://www.eventshigh.com/mumbai/adventure+and+sports', 'https://www.eventshigh.com/detail/mumbai/00c231ada45a7582cb88635ded585d18-scuba-diving-para-sailing-tour?src=ecbox', 'https://www.eventshigh.com/mumbai/outdoors?src=cat-pill', 'https://www.eventshigh.com/detail/mumbai/00c231ada45a7582cb88635ded585d18-scuba-diving-para-sailing-tour?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/4311dbaa31675a1e96419f77d21a2915-mumbai-dandeli-adventures-water-sports?src=ecbox', 'https://www.eventshigh.com/mumbai/sports?src=cat-pill', 'https://www.eventshigh.com/detail/mumbai/4311dbaa31675a1e96419f77d21a2915-mumbai-dandeli-adventures-water-sports?src=ecbox', 'https://www.eventshigh.com/detail/mumbai/fe0cd3bcb128e901438762c8bdc4e454-mumbai-the-swag ...

# %%
def mysqlConnectionInit():
    try:
        db_connection = mysql.connector.connect(
            host="localhost",
            user="root",
            passwd="1919",
            database="pythontwo"
        )
        print("Database connection is OK!")
        return db_connection
    except:
        print("Somting wrong in database connection")
        
mydb = mysqlConnectionInit()
mycursor = mydb.cursor()
# Out:
# Database connection is OK!

# %%
website = 'eventshigh.com'

def Interesting_url():
    for url in interesting_urls:
        sql = "SELECT * FROM interesting_url WHERE url = %s AND website = %s"
        val = (url, website, )
        mycursor.execute(sql, val)
        myresult = mycursor.fetchall()
        if(len(myresult) == 0):
            # print('Insertable')
            sql = "INSERT INTO interesting_url (url, website, status) VALUES (%s, %s, %s)"
            val = (url, website, 0)
            try:
                mycursor.execute(sql, val)
                mydb.commit()
                print("Interesting urls inserted")
            except:
                print('Somthing Worng ! Unable to Insert Intersting URLs')


            

Interesting_url()
# Out:
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted
# Interesting urls inserted

# %%
def Non_nteresting_url():
    for url in non_interesting_urls:
        sql = "SELECT * FROM non_interesting_url WHERE url = %s AND website = %s"
        val = (url, website, )
        mycursor.execute(sql, val)
        myresult = mycursor.fetchall()
        if(len(myresult) == 0):
            # print('Insertable')
            sql = "INSERT INTO non_interesting_url (url, website) VALUES (%s, %s)"
            val = (url, website)
            try:
                mycursor.execute(sql, val)
                mydb.commit()
                print("Non Interesting urls inserted")
            except:
                print('Somthing Worng ! Unable to Insert Non-Intersting URLs')

Non_nteresting_url()
# Out:
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted
# Non Interesting urls inserted

# %%
all_data = []
def scarping_single_event():
    sql = "SELECT * FROM interesting_url WHERE status = %s AND website = %s LIMIT 10"
    val = (0, website, )
    mycursor.execute(sql, val)
    myresult = mycursor.fetchall()
#     print(myresult)
    events_url = []
    for event in myresult:
        event_url = event[1]
        events_url.append(event_url)
#     print(events_url)
    for i in tqdm(range(len(events_url))):
        details = requests.get(events_url[i])
        details_soup = BS(details.text, 'html.parser')
        data = details_soup.find_all("script", {'type': 'application/ld+json'})
        data = '{ "ALLDATA": '+ data[2].text+ '}'
        data = json.loads(data)
        data = data["ALLDATA"][0]
    #     print(data)
        organizer = data["performer"][0]['name']
        title = data['name']
        url = data['url']
        address = data['location']['name']
        price = data["offers"][0]["price"]
        image = data["image"]
        starting_date_time = data["startDate"]
        ending_date_time = data["endDate"]

        all_data.append({'organizer': organizer, 'title': title, 'url': url, 'address': address, 'price': price, 'image': image, 'starting_date_time': starting_date_time, 'ending_date_time': ending_date_time })
        sql = "UPDATE interesting_url SET status = %s WHERE url = %s"
        val = (1, events_url[i], )
        mycursor.execute(sql, val)
        mydb.commit()
        
    
scarping_single_event()
# print(all_data)
# Out:
# 100%|██████████| 10/10 [00:09<00:00,  1.02it/s]

# %%
def insert_event_detail():
    for event in all_data:
#         print(event['url'], '\n')
        url = event['url']
        sql = "SELECT * FROM eventshigh_com WHERE url = %s"
        val = (url, )
        mycursor.execute(sql, val)
        myresult = mycursor.fetchall()
        
        if(len(myresult) == 0):
            sql = "INSERT INTO eventshigh_com (title, organizer, url, address, price, starting_date_time, ending_date_time) VALUES (%s, %s, %s, %s, %s, %s, %s)"
            val = (event['title'], event['organizer'], event['url'], event['address'], event['price'], event['starting_date_time'], event['ending_date_time'])
            try:
                mycursor.execute(sql, val)
                mydb.commit()
                print("Storing Event Details Is Done. Congaratulations!")
            except:
                print("Faild to insert data")
            
            
insert_event_detail()
